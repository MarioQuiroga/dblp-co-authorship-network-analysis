# %% [markdown]
# ### Correlation of degree of the authors

# %%
import networkx as nx
from utils import *

# %%
# %matplotlib inline
graphs = load_networks('../graph')
for name, graph in graphs.items():
    print(graph.number_of_nodes())
    print(graph.number_of_edges())
    compute_degree_correlation(name, graph)
    print("--------------------------------------------------------------")
#g = graphs['google']
#print(g.number_of_nodes())
#print(g.number_of_edges())
#compute_degree_correlation('Univ', g)
#g = nx.read_edgelist('../graph/facebook_combined.txt')
#print("Cantidad de nodos:", g.number_of_nodes())
#print("Cantidad de aristas:", g.number_of_edges())
#print("Grado promedio:", compute_avg_degree(g))
# Density
#print("Densidad:", nx.density(g))
#compute_degree_correlation('Univ', g)
# Out:
# 130
# 214
# 18
# --------------------------------------------------------------
# 149
# 450
# 22
# --------------------------------------------------------------
# 87
# 199
# 15
# --------------------------------------------------------------
# 79
# 182
# 16
# --------------------------------------------------------------
# 466
# 346
# 9
# --------------------------------------------------------------
# 877
# 1767
# 49
# --------------------------------------------------------------
# 1780
# 3158
# 49
# --------------------------------------------------------------
